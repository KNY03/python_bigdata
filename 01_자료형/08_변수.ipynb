# %%
# 변수는 어떻게 만들까?

a = 1
b = "python"
c = [1, 2, 3]

# %%
# 변수명 규칙
# 1. 영문자, 숫자, 언더스코어(_)만 사용 가능
# 2. 숫자로 시작할 수 없음
# 3. 예약어는 사용할 수 없음
# 4. 대소문자 구분

# %%
a, b = "python", "Life"

# %%
print(a)
print(b)
# Out:
# python
# Life

# %%
[a, b] = ["python", "life"]
print(a)
print(b)
# Out:
# python
# life
