# %%
# pip install
# %pip install SomePackage
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for SomePackage: filename=somepackage-1.2.3-py3-none-any.whl size=9359 sha256=33a6a3ad3c764840be2aef70720776e6dbc9b000566520dd6d4c60005cceed78
#   Stored in directory: c:\users\nt371b5a\appdata\local\pip\cache\wheels\a7\83\76\505cb3c27a317975c4433e10969145d3dfd7ca69705c80a03b
# Successfully built SomePackage
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# pip install 패키지명 -> 설치
# pip uninstall 패키지명 -> 삭제
# pip uninstall 패키지명==version -> 특정 버전 설치
# pip list -> 설치된 패케지 list 확인

# %%
# !pip install Faker
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    -------------------------- ------------- 1.3/2.0 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 11.7 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
# ...

# %%
# from faker import Faker
import faker

# fake = Faker()
# fake.name()
# fake.address()

# for _ in range(10):
#     print(fake.name())

a = faker.Faker()
a.name()
# Out:
# 'Cheryl Holland'
