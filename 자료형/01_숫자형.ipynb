# %%
a = 123
print("hello")
# Out:
# hello

# %%
#정수형 

a = 123
b = -178
c = 0

print(a)
print(b)
print(c)

type(a)
# Out:
# 123
# -178
# 0
# int

# %%
#실수형

a = 1.2
b = -3.45

print(a)
print(b)

type(a)
# Out:
# 1.2
# -3.45
# float

# %%
# 8진수와 16진수

a = 0o123 # -> 1 * 8**2 + 2 * 8 + 3
b = 1 * 8**2 + 2 * 8 + 3
# 1, 2, 3, ... , 9, A, B, C, ..
f = 0xF

c = 0x111 # 1 * 16**2 + 16 * 1 + 1
d = 1 * 16**2 + 16 * 1 + 1

print(a)
print(c)
print(f)
# Out:
# 83
# 273
# 15

# %%
#사칙연산

a = 3
b = 4

print(a + b)
print(a - b)
print(a * b)
print(a / b)
# Out:
# 7
# -1
# 12
# 0.75

# %%
#x의 y제곱을 나타내는 제곱(**) 연산자

a = 3
b = 4

print(a**b)
# Out:
# 81

# %%
#나머지 구하는 연산자
7 % 3
print(7 % 3)
print(3 % 2)
# Out:
# 1
# 1

# %%
#몫을 구하는 연산자
print(7 // 4)
# Out:
# 1

# %%
#복합연산자

a = 1
a += 1

# a = a + 1
# a의 더하기 1
# +=
# -=
# *=
# /=

print(a)
# Out:
# 2
